# %%
#import sys
#!{sys.executable} -m pip install -U pip
#!{sys.executable} -m pip install pandas numpy

# %%
# Notebook käivitamine (VS Code / JupyterLab / browser):
# - Run All (või jooksuta järjest)
# - Viimased 4 celli peavad ekraanile kuvama A–D väljundid

# %%
# Cell 1: paths
from pathlib import Path
import pandas as pd
import json

# kohanda kui vaja
IN_CSV = "toorandmed_aasta.csv"          # või "data/toorandmed_aasta.csv"
CONFIG = "cleaner_config.json"
OUTDIR = "out"

Path(OUTDIR).mkdir(exist_ok=True)

# %%
# Cell 2: run cleaning script (py eraldi failina)
import sys

cmd = f'{sys.executable} cleaner_configurable.py --in "{IN_CSV}" --config "{CONFIG}" --lang both --outdir "{OUTDIR}"'
print(cmd)
# !{cmd}
# Out:
# /home/reimoz/.venvs/jupyter/bin/python cleaner_configurable.py --in "toorandmed_aasta.csv" --config "cleaner_config.json" --lang both --outdir "out"
# Wrote:
#  - out/courses_cleaned_full.csv
#  - out/courses_metadata.csv
#  - out/courses_documents.csv
#  - out/clean_report.json

# %%
# Cell 3: load outputs
df_full = pd.read_csv(f"{OUTDIR}/courses_cleaned_full.csv")
df_meta = pd.read_csv(f"{OUTDIR}/courses_metadata.csv")
df_docs = pd.read_csv(f"{OUTDIR}/courses_documents.csv")

with open(f"{OUTDIR}/clean_report.json", "r", encoding="utf-8") as f:
    rep = json.load(f)

(df_full.shape, df_meta.shape, df_docs.shape, rep.keys())
# Out:
# ((3135, 232),
#  (3135, 21),
#  (3135, 11),
#  dict_keys(['dropped', 'kept_rows', 'input_rows', 'lang', 'json_flattened_cols', 'missing_by_column_top', 'categoricals', 'document_text_length_stats']))

# %%
#RAPORT

# %%
#Puuduvate väärtuste hulk igas veerus

# %%
# LAST CELLS - A) Missing values per column
missing = df_full.isna().sum().sort_values(ascending=False)
missing_pct = (missing / len(df_full) * 100).round(2)
missing_table = pd.DataFrame({"missing": missing, "missing_%": missing_pct})
missing_table
# Out:
#                                                missing  missing_%
# title__es                                         3135      100.0
# version__title__es                                3135      100.0
# version__overview__description__es                3135      100.0
# overview__description__es                         3135      100.0
# version__additional_info__study_levels__names     3135      100.0
# ...                                                ...        ...
# version___actions__is_editable                       0        0.0
# version__parent_code                                 0        0.0
# version__grading__assessment_scale__code             0        0.0
# version__grading__assessment_scale__en               0        0.0
# version__additional_info__study_levels__count        0        0.0
#
# [232 rows x 2 columns]

# %%
#Kategooriliste veergude enim levinud väärtused (head(5))

# %%
# LAST CELLS - B) Categoricals top values (head 5)
cat_cols = [
    "version__target__language__code",
    "version__target__semester__code",
    "version__target__faculty__city",
    "additional_info__assessment_scale__code",
    "study_levels__codes",
    "version__additional_info__study_levels__codes"
]

for c in cat_cols:
    print("\n==", c, "==")
    if c in df_full.columns:
        display(df_full[c].fillna("").astype(str).str.strip().value_counts().head(5))
    else:
        print("MISSING COLUMN")
# Out:
# == version__target__language__code ==
# version__target__language__code
# et    2326
# en     809
# Name: count, dtype: int64
# == version__target__semester__code ==
# version__target__semester__code
# spring    1570
# autumn    1565
# Name: count, dtype: int64
# == version__target__faculty__city ==
# version__target__faculty__city
# Tartu linn    3134
# Tartu            1
# Name: count, dtype: int64
# == additional_info__assessment_scale__code ==
# additional_info__assessment_scale__code
# grade      1858
# pass       1276
# defence       1
# Name: count, dtype: int64
# == study_levels__codes ==
# MISSING COLUMN
#
# == version__additional_info__study_levels__codes ==
# version__additional_info__study_levels__codes
# bachelor                    970
# master                      576
# bachelor;master             320
# bachelor_master             260
# bachelor;doctoral;master    217
# Name: count, dtype: int64

# %%
#“Sissejuhatus datasetisse”: ühe aine kirje loetaval kujul (mitte lihtsalt raw print)

# %%
# LAST CELLS - C) One example course, readable
import textwrap
import numpy as np

# vali rida, millel document_text on pikk (et näidis oleks sisukas)
ix = df_docs["document_text"].fillna("").astype(str).str.len().sort_values(ascending=False).index[0]

row_full = df_full.loc[ix].to_dict()
row_meta = df_meta.loc[ix].to_dict() if ix in df_meta.index else {}
row_doc  = df_docs.loc[ix].to_dict()

def pretty_kv(d, keys=None, width=110):
    if keys is None:
        keys = list(d.keys())
    lines = []
    for k in keys:
        v = d.get(k, "")
        if isinstance(v, float) and np.isnan(v):
            v = ""
        s = f"{k}: {v}"
        lines.append(textwrap.fill(s, width=width, subsequent_indent="  "))
    return "\n".join(lines)

# vali näitamiseks “mõistlik” alamhulk (muuda kui tahad)
meta_keys = [k for k in [
    "code", "version__code", "course_uuid", "version__uuid",
    "version__target__semester__code", "version__target__language__code",
    "version__target__faculty__city", "additional_info__assessment_scale__code",
    "study_levels__codes", "version__additional_info__study_levels__codes",
] if k in row_meta]

print("### Näidis aine: METADATA ###\n")
print(pretty_kv(row_meta, keys=meta_keys))

print("\n\n### Näidis aine: DOCUMENT_TEXT ###\n")
print(textwrap.fill(str(row_doc.get("document_text", "")), width=110))
# Out:
# ### Näidis aine: METADATA ###
#
# code: SVUH.00.111
# version__code: sv-2025-spring-fulltime
# course_uuid: 32a3a779-112d-20a3-13ef-92e39df5062f
# version__uuid: 4da518b8-7606-cb46-0119-f6fe09c73150
# version__target__semester__code: spring
# version__target__language__code: et
# version__target__faculty__city: Tartu linn
# additional_info__assessment_scale__code: grade
# study_levels__codes: bachelor
# version__additional_info__study_levels__codes: bachelor
#
#
# ### Näidis aine: DOCUMENT_TEXT ###
#
# Pealkiri: Praktiline ajakirjandus II Title: Practical Journalism II Kirjeldus: Kursus toimub neljas osas, aga
# kahes jaotuses (praktiline ajakirjandus I ja II): esimene osa keskendub uudisele kirjutavas meediumis, teine
# osa uudisele audiomeediumis, kolmas uudisele audiovisuaalses meediumis ja neljas digimeedias. Mõtteliselt on
# iga osa 6 EAP vääriline. 1) uudis kirjutavas meediumis: tudengid töötavad nädalas ühe täispäeva kui reaalne
# toimetus, otsides kajastamisväärseid sündmusi, tehes reporteritööd ning kirjutades sama päeva õhtuks valmis
# uudise. 2) uudis audiomeediumis: tutvustatakse audiouudise tegemise põhimõisteid ja aluseid. Praktiliste tööde
# abil omandatakse ja kinnistatakse oskusi tekstuudise ja salvestatud uudismaterjali tegemiseks, samuti
# toimetamisoskusi. 3) uudis audiovisuaalses meediumis: igal nädalal kahel õppepäeval toimuv kursus keskendub
# uudisväärtusliku sündmuse leidmisele ja selle vormistamisele audiovisuaalseks uudiseks. 4) uudis digimeedias:
# kaasaegne ajakirjandus ja digimeedia. Digimeedia arengud ja üleminekud trükimeedialt digile. Trendid
# digimeedias. Kommunikatsiooniprotsessid ja -ahelad meediaorganisatsioonis. Sihtrühmad, trendid. Eri allikate
# kasutamine. erinevate meedialiikide ja sündmuste kajastamine. Erakorraliste sündmuste ja kriiside kajastuste
# õppetunnid ja nende ära kasutamine igapäevatöös. 5) tehniliste vahendite kasutamine; toimub lõimituna terve
# kursuse jooksul. Produktsiooni ja postproduktsiooni võtete ja kasutatavate seadmete tundma- ja
# kasutamaõppimine konkreetsete õppeülesannete täitmiseks ning edaspidiseks rakkepädevuseks. Erinevate osade
# täpsem kirjeldus on esitatud vastava osa aineprogrammis. Description: The course is divided into four parts
# across two sections (Practical Journalism I and II): The first part focuses on news in written media, the
# second on news in audio media, the third on news in audiovisual media, and the fourth on digital media.
# Conceptually, each part corresponds to 6 ECTS credits. 1. News in written media: Students work one full day
# per week as a real newsroom, identifying newsworthy events, performing reporting tasks, and writing a
# completed news story by the evening of the same day. 2. News in audio media: Introduces the key concepts and
# principles of creating audio news. Through practical exercises, students acquire and reinforce skills in
# producing text-based news, recorded news material, and editing. 3. News in audiovisual media: A twice-weekly
# course focusing on identifying newsworthy events and transforming them into audiovisual news pieces. 4. News
# in digital media: Modern journalism and digital media. Developments and transitions from print to digital
# media. Trends in digital media. Communication processes and chains in media organizations. Target audiences,
# trends, use of diverse sources, and coverage of different media types and events. Lessons from reporting on
# exceptional events and crises, and their application in everyday work. 5. Use of technical tools: This aspect
# is integrated throughout the course. It involves learning and applying production and post-production
# techniques and equipment to complete specific course assignments and build future professional competency.
# Detailed descriptions of each part are provided in the respective course syllabi. Eesmärgid: [{"en": "Provide
# students with practical skills for reporting in written media (including online), audio media, and audiovisual
# media. The course teaches how to prepare, compose, and present publishable news.", "et": "Anda tudengitele
# praktilised oskused reporteritööks kirjutavas meediumis (sh veebis), audiomeediumis ja audiovisuaalses
# meediums. Kursusel õpetatakse kuidas valmistada ette, koostada ja esitada avaldamiskõlblikku uudist."}]
# Objectives: - Provide students with practical skills for reporting in written media (including online), audio
# media, and audiovisual media. The course teaches how to prepare, compose, and present publishable news.
# Õpiväljundid: [{"en": "Student who successfully finishes the course:", "et": "Kursuse edukalt läbinud
# tudeng:"}, {"en": "- knows how to find newsworthy material, knows how to frame it and set focus according to
# news values; ", "et": "- oskab leida, raamistada ja fookustada uudist;"}, {"en": "- comprehends the importance
# of groundwork and is skilled in working with different kind of sources;", "et": "- mõistab
# taustainformatsiooni kogumise olulisust ning oskab töötada erinevate allikatega;"}, {"en": "- is skilled in
# evaluating sources and manages different interviewing techniques;", "et": "- oskab hinnata ja valida allikaid
# ning mõistab kasutada erinevaid intervjueerimisvõtteid;"}, {"en": "- has the knowledge of time planning and
# working under deadline pressure;", "et": "- oskab planeerida aega, mõistab tähtaegade olulisust ajakirjanduses
# ning oskab ajasurve all töötada;"}, {"en": "- knows how to compose a news story according to hard news
# conventions, knows how to check the facts and edit the material linguistically.", "et": "- oskab vormistada ja
# klassikalise kõva uudise konventsioonidele vastavat uudist ning seda faktiliselt ja keeleliselt toimetada."},
# {"en": "- is able to write and express assignments in correct Estonian, following the norms and rules of the
# Estonian language. The course is based on the Estonian Orthography Dictionary.", "et": "- oskab vormistada
# tööd korrektses eesti keeles, jälgides eesti keele norme ja reegleid. Kursus toetub
# Õigekeelsussõnaraamatule."}] Learning outcomes: - Student who successfully finishes the course: - - knows how
# to find newsworthy material, knows how to frame it and set focus according to news values; - - comprehends the
# importance of groundwork and is skilled in working with different kind of sources; - - is skilled in
# evaluating sources and manages different interviewing techniques; - - has the knowledge of time planning and
# working under deadline pressure; - - knows how to compose a news story according to hard news conventions,
# knows how to check the facts and edit the material linguistically. - - is able to write and express
# assignments in correct Estonian, following the norms and rules of the Estonian language. The course is based
# on the Estonian Orthography Dictionary. Eeldusained: [{"alternatives": [{"code": "SOZU.01.193", "credits": 5,
# "last_update": "2024-04-24T14:33:53", "state": {"code": "closed", "en": "closed", "et": "Suletud"}, "title":
# {"en": "Basics of News Writing", "et": "Uudise alused"}, "type": {"code": "regular", "en": "Regular course",
# "et": "Tavaline aine"}, "uuid": "5ccbdd80-aa8b-a36c-d477-2767788435b4"}], "code": "SVUH.00.213", "credits": 6,
# "last_update": "2024-02-05T11:04:36", "required": true, "state": {"code": "confirmed", "en": "confirmed",
# "et": "Kinnitatud"}, "title": {"en": "Foundations of Journalism", "et": "Ajakirjanduse alused"}, "uuid":
# "dec8c897-d4f5-41c1-c72a-57db39ccaebd"}, {"alternatives": [{"code": "SVUH.00.215", "credits": 6,
# "last_update": "2024-02-05T11:04:36", "state": {"code": "confirmed", "en": "confirmed", "et": "Kinnitatud"},
# "title": {"en": "Interviewing Techniques", "et": "Kuulamistreening ja intervjueerimine"}, "type": {"code":
# "regular", "en": "Regular course", "et": "Tavaline aine"}, "uuid": "096a8f08-b55f-c7d8-69c7-314972d054bd"}],
# "code": "SHZU.01.015", "credits": 5, "last_update": "2024-04-02T11:36:38", "required": true, "state": {"code":
# "closed", "en": "closed", "et": "Suletud"}, "title": {"en": "Interviewing Techniques", "et": "Kuulamistreening
# ja intervjueerimine"}, "uuid": "695fc6fa-0eed-4583-46a4-ca0b587742e8"}, {"alternatives": [{"code":
# "SVUH.00.225", "credits": 6, "last_update": "2024-02-05T11:04:36", "state": {"code": "confirmed", "en":
# "confirmed", "et": "Kinnitatud"}, "title": {"en": "Introduction to Audiovisual Media", "et": "Sissejuhatus
# audiovisuaalsesse meediasse"}, "type": {"code": "regular", "en": "Regular course", "et": "Tavaline aine"},
# "uuid": "2079d871-fdb0-dfe9-7849-9a800ed9344c"}, {"code": "SOZU.01.192", "credits": 6, "last_update":
# "2024-02-05T11:04:36", "state": {"code": "closed", "en": "closed", "et": "Suletud"}, "title": {"en":
# "Introduction to Audiovisual Communication", "et": "Ülevaade audiovisuaalsest kommunikatsioonist"}, "type":
# {"code": "regular", "en": "Regular course", "et": "Tavaline aine"}, "uuid":
# "427b3a2d-ebbb-e06a-9fe9-190f9a39f22c"}, {"code": "SVUH.00.102", "credits": 4, "last_update":
# "2024-02-05T11:04:36", "state": {"code": "closed", "en": "closed", "et": "Suletud"}, "title": {"en": "Public
# Audiovisual Media", "et": "Audiovisuaalne meedia avalikus ruumis"}, "type": {"code": "regular", "en": "Regular
# course", "et": "Tavaline aine"}, "uuid": "ef2e1ded-9620-ba85-40a5-a2afb54500bd"}, {"code": "SVUH.00.140",
# "credits": 3, "last_update": "2025-04-11T14:29:46", "state": {"code": "closed", "en": "closed", "et":
# "Suletud"}, "title": {"en": "Public Audiovisual Media", "et": "Audiovisuaalne meedia avalikus ruumis"},
# "type": {"code": "regular", "en": "Regular course", "et": "Tavaline aine"}, "uuid":
# "3a4c2141-bd83-cedf-e012-fb2b4b584460"}], "code": "SVUH.00.109", "credits": 2, "last_update":
# "2025-04-11T14:25:04", "required": true, "state": {"code": "closed", "en": "closed", "et": "Suletud"},
# "title": {"en": "Public Audiovisual Media (minor field)", "et": "Audiovisuaalne meedia avalikus ruumis
# kõrvalerialale"}, "uuid": "8319f376-0a6e-80e9-d2a5-05cb0ab10346"}, {"alternatives": [{"code": "SVUH.00.139",
# "credits": 3, "last_update": "2025-04-11T14:41:43", "state": {"code": "closed", "en": "closed", "et":
# "Suletud"}, "title": {"en": "Introduction to Audio Media", "et": "Sissejuhatus audiomeediasse"}, "type":
# {"code": "regular", "en": "Regular course", "et": "Tavaline aine"}, "uuid":
# "2fb05859-b791-05c8-4837-76e19b658112"}, {"code": "SVUH.00.225", "credits": 6, "last_update":
# "2024-02-05T11:04:36", "state": {"code": "confirmed", "en": "confirmed", "et": "Kinnitatud"}, "title": {"en":
# "Introduction to Audiovisual Media", "et": "Sissejuhatus audiovisuaalsesse meediasse"}, "type": {"code":
# "regular", "en": "Regular course", "et": "Tavaline aine"}, "uuid": "2079d871-fdb0-dfe9-7849-9a800ed9344c"},
# {"code": "SVUH.00.101", "credits": 4, "last_update": "2024-02-05T11:04:36", "state": {"code": "closed", "en":
# "closed", "et": "Suletud"}, "title": {"en": "Introduction to Audio Media", "et": "Sissejuhatus
# audiomeediasse"}, "type": {"code": "regular", "en": "Regular course", "et": "Tavaline aine"}, "uuid":
# "9cfc5c41-78f3-198a-68f6-4ef64f70903f"}], "code": "SVUH.00.108", "credits": 2, "last_update":
# "2025-04-11T14:41:58", "required": true, "state": {"code": "closed", "en": "closed", "et": "Suletud"},
# "title": {"en": "Introduction to Audio Media (Minor Field)", "et": "Sissejuhatus audiomeediasse
# kõrvalerialale"}, "uuid": "fbb02676-c61e-038a-d522-b8a7def938bc"}, {"code": "SVUH.00.110", "credits": 12,
# "last_update": "2024-08-21T14:23:50", "required": true, "state": {"code": "confirmed", "en": "confirmed",
# "et": "Kinnitatud"}, "title": {"en": "Practical Journalism I", "et": "Praktiline ajakirjandus I"}, "uuid":
# "8d1e0a26-c93e-82a7-a524-6e7bb6812f59"}] Prerequisites: [{"alternatives": [{"code": "SOZU.01.193", "credits":
# 5, "last_update": "2024-04-24T14:33:53", "state": {"code": "closed", "en": "closed", "et": "Suletud"},
# "title": {"en": "Basics of News Writing", "et": "Uudise alused"}, "type": {"code": "regular", "en": "Regular
# course", "et": "Tavaline aine"}, "uuid": "5ccbdd80-aa8b-a36c-d477-2767788435b4"}], "code": "SVUH.00.213",
# "credits": 6, "last_update": "2024-02-05T11:04:36", "required": true, "state": {"code": "confirmed", "en":
# "confirmed", "et": "Kinnitatud"}, "title": {"en": "Foundations of Journalism", "et": "Ajakirjanduse alused"},
# "uuid": "dec8c897-d4f5-41c1-c72a-57db39ccaebd"}, {"alternatives": [{"code": "SVUH.00.215", "credits": 6,
# "last_update": "2024-02-05T11:04:36", "state": {"code": "confirmed", "en": "confirmed", "et": "Kinnitatud"},
# "title": {"en": "Interviewing Techniques", "et": "Kuulamistreening ja intervjueerimine"}, "type": {"code":
# "regular", "en": "Regular course", "et": "Tavaline aine"}, "uuid": "096a8f08-b55f-c7d8-69c7-314972d054bd"}],
# "code": "SHZU.01.015", "credits": 5, "last_update": "2024-04-02T11:36:38", "required": true, "state": {"code":
# "closed", "en": "closed", "et": "Suletud"}, "title": {"en": "Interviewing Techniques", "et": "Kuulamistreening
# ja intervjueerimine"}, "uuid": "695fc6fa-0eed-4583-46a4-ca0b587742e8"}, {"alternatives": [{"code":
# "SVUH.00.225", "credits": 6, "last_update": "2024-02-05T11:04:36", "state": {"code": "confirmed", "en":
# "confirmed", "et": "Kinnitatud"}, "title": {"en": "Introduction to Audiovisual Media", "et": "Sissejuhatus
# audiovisuaalsesse meediasse"}, "type": {"code": "regular", "en": "Regular course", "et": "Tavaline aine"},
# "uuid": "2079d871-fdb0-dfe9-7849-9a800ed9344c"}, {"code": "SOZU.01.192", "credits": 6, "last_update":
# "2024-02-05T11:04:36", "state": {"code": "closed", "en": "closed", "et": "Suletud"}, "title": {"en":
# "Introduction to Audiovisual Communication", "et": "Ülevaade audiovisuaalsest kommunikatsioonist"}, "type":
# {"code": "regular", "en": "Regular course", "et": "Tavaline aine"}, "uuid":
# "427b3a2d-ebbb-e06a-9fe9-190f9a39f22c"}, {"code": "SVUH.00.102", "credits": 4, "last_update":
# "2024-02-05T11:04:36", "state": {"code": "closed", "en": "closed", "et": "Suletud"}, "title": {"en": "Public
# Audiovisual Media", "et": "Audiovisuaalne meedia avalikus ruumis"}, "type": {"code": "regular", "en": "Regular
# course", "et": "Tavaline aine"}, "uuid": "ef2e1ded-9620-ba85-40a5-a2afb54500bd"}, {"code": "SVUH.00.140",
# "credits": 3, "last_update": "2025-04-11T14:29:46", "state": {"code": "closed", "en": "closed", "et":
# "Suletud"}, "title": {"en": "Public Audiovisual Media", "et": "Audiovisuaalne meedia avalikus ruumis"},
# "type": {"code": "regular", "en": "Regular course", "et": "Tavaline aine"}, "uuid":
# "3a4c2141-bd83-cedf-e012-fb2b4b584460"}], "code": "SVUH.00.109", "credits": 2, "last_update":
# "2025-04-11T14:25:04", "required": true, "state": {"code": "closed", "en": "closed", "et": "Suletud"},
# "title": {"en": "Public Audiovisual Media (minor field)", "et": "Audiovisuaalne meedia avalikus ruumis
# kõrvalerialale"}, "uuid": "8319f376-0a6e-80e9-d2a5-05cb0ab10346"}, {"alternatives": [{"code": "SVUH.00.139",
# "credits": 3, "last_update": "2025-04-11T14:41:43", "state": {"code": "closed", "en": "closed", "et":
# "Suletud"}, "title": {"en": "Introduction to Audio Media", "et": "Sissejuhatus audiomeediasse"}, "type":
# {"code": "regular", "en": "Regular course", "et": "Tavaline aine"}, "uuid":
# "2fb05859-b791-05c8-4837-76e19b658112"}, {"code": "SVUH.00.225", "credits": 6, "last_update":
# "2024-02-05T11:04:36", "state": {"code": "confirmed", "en": "confirmed", "et": "Kinnitatud"}, "title": {"en":
# "Introduction to Audiovisual Media", "et": "Sissejuhatus audiovisuaalsesse meediasse"}, "type": {"code":
# "regular", "en": "Regular course", "et": "Tavaline aine"}, "uuid": "2079d871-fdb0-dfe9-7849-9a800ed9344c"},
# {"code": "SVUH.00.101", "credits": 4, "last_update": "2024-02-05T11:04:36", "state": {"code": "closed", "en":
# "closed", "et": "Suletud"}, "title": {"en": "Introduction to Audio Media", "et": "Sissejuhatus
# audiomeediasse"}, "type": {"code": "regular", "en": "Regular course", "et": "Tavaline aine"}, "uuid":
# "9cfc5c41-78f3-198a-68f6-4ef64f70903f"}], "code": "SVUH.00.108", "credits": 2, "last_update":
# "2025-04-11T14:41:58", "required": true, "state": {"code": "closed", "en": "closed", "et": "Suletud"},
# "title": {"en": "Introduction to Audio Media (Minor Field)", "et": "Sissejuhatus audiomeediasse
# kõrvalerialale"}, "uuid": "fbb02676-c61e-038a-d522-b8a7def938bc"}, {"code": "SVUH.00.110", "credits": 12,
# "last_update": "2024-08-21T14:23:50", "required": true, "state": {"code": "confirmed", "en": "confirmed",
# "et": "Kinnitatud"}, "title": {"en": "Practical Journalism I", "et": "Praktiline ajakirjandus I"}, "uuid":
# "8d1e0a26-c93e-82a7-a524-6e7bb6812f59"}]

# %%
#document_text tähemärkide arvu statistika (describe + percentiilid)

# %%
# LAST CELLS - D) document_text length stats
lens = df_docs["document_text"].fillna("").astype(str).str.len()
lens.describe(percentiles=[0.25, 0.5, 0.75, 0.9, 0.95, 0.99])
# Out:
# count     3135.000000
# mean      3229.053270
# std       1737.625635
# min        189.000000
# 25%       2045.000000
# 50%       2834.000000
# 75%       3980.000000
# 90%       5458.600000
# 95%       6570.700000
# 99%       9005.820000
# max      15891.000000
# Name: document_text, dtype: float64
